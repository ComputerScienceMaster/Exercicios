# 3 * 5 = 15
# 4 * 5 = 20
# 5 * 5 = 25
# 6 * 5 = 30
# 7 * 5 = 35
# 8 * 5 = 40
# 9 * 5 = 45

# %%
# 3- Faça um programa que mostre as tabuadas dos números de 1 a 10.

for i in range (1,10):
    print("\n")
    for j in range(1,10):
        print(i, "*", j, "=", i*j)
# Out:
# 1 * 1 = 1
# 1 * 2 = 2
# 1 * 3 = 3
# 1 * 4 = 4
# 1 * 5 = 5
# 1 * 6 = 6
# 1 * 7 = 7
# 1 * 8 = 8
# 1 * 9 = 9
#
#
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
#
#
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
#
#
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 4 * 8 = 32
# 4 * 9 = 36
#
#
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
#
#
# 6 * 1 = 6
# 6 * 2 = 12
# 6 * 3 = 18
# 6 * 4 = 24
# 6 * 5 = 30
# 6 * 6 = 36
# 6 * 7 = 42
# 6 * 8 = 48
# 6 * 9 = 54
#
#
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63
#
#
# 8 * 1 = 8
# 8 * 2 = 16
# 8 * 3 = 24
# 8 * 4 = 32
# 8 * 5 = 40
# 8 * 6 = 48
# 8 * 7 = 56
# 8 * 8 = 64
# 8 * 9 = 72
#
#
# 9 * 1 = 9
# 9 * 2 = 18
# 9 * 3 = 27
# 9 * 4 = 36
# 9 * 5 = 45
# 9 * 6 = 54
# 9 * 7 = 63
# 9 * 8 = 72
# 9 * 9 = 81

# %%
# 4- Uma loja tem tem uma política de descontos de acordo com o valor da compra do cliente. Os descontos começam acima dos R$500
# A cada 100 reais acima dos R$500,00 o cliente ganha 1% de desconto cumulativo até 25%. 
# Por exemplo: R$500 = 1% || R$600,00 = 2% ... etc...

# Faça um programa que exiba essa tabela de descontos no seguinte formato:  
# Valordacompra - porcentagem de desconto - valor final

valordacompra = 500

for i in range(1,26):
    print("valor da compra: ", valordacompra, "porcentagem de desconto:", i, "valor final", valordacompra *(1-(i/100)))
    valordacompra = valordacompra +100
# Out:
# valor da compra:  500 porcentagem de desconto: 1 valor final 495.0
# valor da compra:  600 porcentagem de desconto: 2 valor final 588.0
# valor da compra:  700 porcentagem de desconto: 3 valor final 679.0
# valor da compra:  800 porcentagem de desconto: 4 valor final 768.0
# valor da compra:  900 porcentagem de desconto: 5 valor final 855.0
# valor da compra:  1000 porcentagem de desconto: 6 valor final 940.0
# valor da compra:  1100 porcentagem de desconto: 7 valor final 1022.9999999999999
# valor da compra:  1200 porcentagem de desconto: 8 valor final 1104.0
# valor da compra:  1300 porcentagem de desconto: 9 valor final 1183.0
# valor da compra:  1400 porcentagem de desconto: 10 valor final 1260.0
# valor da compra:  1500 porcentagem de desconto: 11 valor final 1335.0
# valor da compra:  1600 porcentagem de desconto: 12 valor final 1408.0
# valor da compra:  1700 porcentagem de desconto: 13 valor final 1479.0
# valor da compra:  1800 porcentagem de desconto: 14 valor final 1548.0
# valor da compra:  1900 porcentagem de desconto: 15 valor final 1615.0
# valor da compra:  2000 porcentagem de desconto: 16 valor final 1680.0
# valor da compra:  2100 porcentagem de desconto: 17 valor final 1743.0
# valor da compra:  2200 porcentagem de desconto: 18 valor final 1804.0000000000002
# valor da compra:  2300 porcentagem de desconto: 19 valor final 1863.0000000000002
# valor da compra:  2400 porcentagem de desconto: 20 valor final 1920.0
# valor da compra:  2500 porcentagem de desconto: 21 valor final 1975.0
# valor da compra:  2600 porcentagem de desconto: 22 valor final 2028.0
# valor da compra:  2700 porcentagem de desconto: 23 valor final 2079.0
# valor da compra:  2800 porcentagem de desconto: 24 valor final 2128.0
# valor da compra:  2900 porcentagem de desconto: 25 valor final 2175.0

# %%
# 5- Uma companhia de teatro deseja dar uma série de espetáculos. 
# Fatos:
# 1) A direção calcula que praticando o preço de R$5,00 serão vendidos 120 ingressos
# 2) As despesas são fixas em R$ 200,00. 
# 3) Ao diminuir R$ 0,50 o preço dos ingressos espera-se que as vendas aumentem em 26 ingressos.

# Faça um programa que escreva uma tabela de valores de lucros esperados em função do preço do ingresso, fazendo-se variar 
# esse preço de R$ 5,00 até R$ 1,00 de R$ 0,50 em R$ 0,50. 

# A tabela deve mostrar:  o lucro máximo esperado || o preço do ingresso || quantidade de ingressos vendidos || 

preco = 5
ingressosVendidos = 120

while preco >1:
    print ("Lucro máximo: ", ingressosVendidos * preco - 200, "preço do ingresso:", preco, "Quantidade de ingressos vendidos", ingressosVendidos)
    preco = preco - 0.5
    ingressosVendidos = ingressosVendidos + 26
# Out:
# Lucro máximo:  400 preço do ingresso: 5 Quantidade de ingressos vendidos 120
# Lucro máximo:  457.0 preço do ingresso: 4.5 Quantidade de ingressos vendidos 146
# Lucro máximo:  488.0 preço do ingresso: 4.0 Quantidade de ingressos vendidos 172
# Lucro máximo:  493.0 preço do ingresso: 3.5 Quantidade de ingressos vendidos 198
# Lucro máximo:  472.0 preço do ingresso: 3.0 Quantidade de ingressos vendidos 224
# Lucro máximo:  425.0 preço do ingresso: 2.5 Quantidade de ingressos vendidos 250
# Lucro máximo:  352.0 preço do ingresso: 2.0 Quantidade de ingressos vendidos 276
# Lucro máximo:  253.0 preço do ingresso: 1.5 Quantidade de ingressos vendidos 302

# %%
# 7- Faça um programa que receba a idade de dez pessoas e que calcule e mostre a quantidade de pessoas com idade maior ou 
# igual a 18 anos.

num =  0
maiorDe18 = 0
menorDe18 = 0
igualA18 = 0 
while num < 3:
    nome = input("Digite o nome da pessoa")
    idade = input("digite a idade do(a)" + nome)
    if int(idade) > 18:
        maiorDe18 = maiorDe18 + 1
    elif int(idade)< 18:
        menorDe18 = menorDe18 + 1
    else:
        igualA18 = igualA18 + 1
    num = num + 1
    
print ("maiores que 18: ", maiorDe18)
print ("menor que 18", menorDe18)
print ("igual a 18", igualA18)
# Out:
# Digite o nome da pessoamaira
# digite a idade do(a)maira12
# Digite o nome da pessoajiji
# digite a idade do(a)jiji9
# Digite o nome da pessoalol
# digite a idade do(a)lol50
# maiores que 18:  1
# menor que 18 2
# igual a 18 0

# %%
# 8-    Faça um programa que receba a idade de 15 pessoas e que calcule e mostre:
#    A quantidade de pessoas em cada faixa etária;
#    A percentagem de pessoas na primeira e na última faixa etária, com relação ao total de pessoas.

#       faixa1 =   Até 15 anos
#       faixa2 =   De 16 a 30 anos
#       faixa3 =   De 31 a 45 anos
#       faixa4 =  De 46 a 60 anos
#       faixa5 =  Acima de 61 anos

faixa1 = 0
faixa2 = 0
faixa3 = 0
faixa4 = 0
faixa5 = 0

for i in range (0,5):
    idadestr = input("digite a idade da pessoa")
    idade = int(idadestr)
    if idade <= 15:
        faixa1 += 1
    elif idade > 15 and idade < 30:
        faixa2 += 1
    elif idade >30 and idade <45:
        faixa3 += 1
    elif idade > 45 and idade <60:
        faixa4 += 1
    else:
        faixa5 += 1 
        
        
print ("até 15 anos", faixa1)
print("De 16 a 30 anos", faixa2)
print("De 31 a 45 anos", faixa3)
print ("De 46 a 60 anos", faixa4)
print ("acima de 61 anos", faixa5)
# Out:
# digite a idade da pessoa15
# digite a idade da pessoa14
# digite a idade da pessoa65
# digite a idade da pessoa51
# digite a idade da pessoa41
# até 15 anos 2
# De 16 a 30 anos 0
# De 31 a 45 anos 1
# De 46 a 60 anos 1
# acima de 61 anos 1

# %%
# 11-  Uma loja utiliza o código V para transação à vista e P para transação a prazo. Faça um programa que receba código e 
# valor de 5 transações. Calcule e mostre:

# a.    O valor total das compras à vista
# b.    O valor total das compras a prazo sabendo que essas compras possuem 10% de juros sobre o valor total
# c.    O valor total das compras efetuadas

aVista = 0 
aPrazo = 0
total = 0

for i in range (0,5):
    tipoDeCompra = input("(p) compra a prazo \n (v) compra a vista \n")
    valorDaCompra = int(input("Digite o valor da compra"))
    if tipoDeCompra == "p":
        aPrazo += valorDaCompra
    elif tipoDeCompra == "v":
        aVista += valorDaCompra * 1.10

    total += valorDaCompra

print("A vista:", aVista)
print("A prazo:", aPrazo)
print("total:", total)
# Out:
# (p) compra a prazo
#  (v) compra a vista
# v
# Digite o valor da compra100
# (p) compra a prazo
#  (v) compra a vista
# v
# Digite o valor da compra1000
# (p) compra a prazo
#  (v) compra a vista
#
# Digite o valor da compra120
# (p) compra a prazo
#  (v) compra a vista
# p
# Digite o valor da compra120
# (p) compra a prazo
#  (v) compra a vista
# p
# Digite o valor da compra51
# A vista: 1210.0
# A prazo: 171
# total: 1391

# %%
# 15- Faça um programa que receba 3 números e que calcule e mostre a quantidade de números entre 30 e 90.

quantidade = 0

for i in range(0,3):
    numero = int(input("Digite um Numero"))
    if( numero > 30 and numero < 90):
        quantidade += 1 
        
print("quantidade de numeros entre 30 e 90:", quantidade)
# Out:
# Digite um Numero10
# Digite um Numero40
# Digite um Numero50
# quantidade de numeros entre 30 e 90: 2

# %%
# 18-  Considerando a sequencia de fibonnaci sendo: 0,1,1,2,3,5,8,13,... Sendo o proximo termo sempre a soma dos dois anteriores
# faça um programa que o usuário digite um numero "n" e o programa exiba n termos dessa sequencia.

n = int(input('digite a quantidade de termos que você deseja imprimir'))

i = 0

a, b = 0, 1
for i in range(0, n):
    a, b = b, a + b
    print(a)
# Out:
# digite a quantidade de termos que você deseja imprimir5
# 1
# 1
# 2
# 3
# 5
